# %%
import pandas as pd
import pickle

# %%
with open('C:/Users/ASUS/anaconda3/data_scentics/data/interim/books_data.pkl', 'rb') as f:
    books_data = pickle.load(f)

with open('C:/Users/ASUS/anaconda3/data_scentics/data/interim/ratings_data.pkl', 'rb') as f:
    ratings_data= pickle.load(f)

with open('C:/Users/ASUS/anaconda3/data_scentics/data/interim/users_data.pkl', 'rb') as f:
    users_data= pickle.load(f)

# %%
# create sample data
sample = ratings_data.sample(n=1000, random_state=42)
ISBN = sample.iloc[1]['ISBN']

# %%
def correlation(ISBN):

    # Filtered subset of ratings_data based on ISBN
    ratings_data_filtered = ratings_data[ratings_data['ISBN'].isin(['0590353403', '0439136350', '0439139597','0439064864', '8445071408'])]

    # Concatenate the filtered subset with the sample DataFrame
    concatenated_df = pd.concat([ratings_data_filtered, sample], ignore_index=True)
    concatenated_df = concatenated_df.drop_duplicates()

    # create pivoted matrix
    pivoted_df = concatenated_df.pivot(index='User-ID', columns='ISBN', values='Book-Rating')
    pivoted_df.fillna(0, inplace=True)
    #pivoted_df

    # calculate correlation matrix
    correlation = pivoted_df.corr()

    correlation = correlation.loc[ISBN].reset_index(name = 'Index')

    correlation  = correlation[(correlation['Index'] > 0) & (correlation['Index'] < 1)]

    books = books_data.loc[books_data['ISBN'].isin(correlation['ISBN'])]

    return(books)

# %%
books_data.loc[books_data['ISBN'] == '0590353403']
# Out:
#             ISBN  Book-Author                                    Book-Title  \
# 2809  0590353403  J.K.ROWLING  HARRY POTTER AND THE SORCERER'S STONE BOOK 1
#
#       Year-Of-Publication   Publisher Language
# 2809                 1998  SCHOLASTIC       EN

# %%
books_data.loc[books_data['ISBN'].isin(sample['ISBN'])]
# Out:
#               ISBN        Book-Author  \
# 26      0971880107        RIC.SHAPERO
# 46      0553582747         DEA.KOONTZ
# 113     0446608653        SANDR.BROWN
# 114     0446612545     JAME.PATTERSON
# 118     0671027360           DA.BROWN
# ...            ...                ...
# 265706  0671660578      SARA.SHANKMAN
# 265891  1883319080   MOSH.FELDENKRAIS
# 266275  0812501810  WALTE.JO.WILLIAMS
# 268349  0373195508        BEVERL.BIRD
# 268559  1576732371     SUSA.WIS.BAUER
#
#                                                Book-Title  \
# 26                                            WILD ANIMUS
# 46                             FROM THE CORNER OF HIS EYE
# 113                                             THE ALIBI
# 114                                       THE BEACH HOUSE
# 118                                   ANGELS &AMP; DEMONS
# ...                                                   ...
# 265706                                    KEEPING SECRETS
# 265891  BODY AWARENESS AS HEALING THERAPY THE CASE OF ...
# 266275                                             FACETS
# 268349         TEN WAYS TO WIN HER MAN SILHOUETTE ROMANCE
# 268559                      THOUGH THE DARKNESS HIDE THEE
#
#         Year-Of-Publication             Publisher Language
# 26                     2004               TOO FAR       EN
# 46                     2001          BANTAM BOOKS       EN
# 113                    2000          WARNER BOOKS       EN
# 114                    2003          WARNER BOOKS       EN
# 118                    2001           POCKET STAR       EN
# ...                     ...                   ...      ...
# 265706                 1988  SIMON &AMP; SCHUSTER       EN
# 265891                 1994  NORTH ATLANTIC BOOKS       EN
# 266275                 1991        TOR BOOKS (MM)       EN
# 268349                 2001            SILHOUETTE       EN
# 268559                 1998             MULTNOMAH       EN
#
# [879 rows x 6 columns]

# %%
ISBN = '0590353403'
correlation(ISBN)
# Out:
#               ISBN        Book-Author  \
# 1721    0060192119      JOH.COLAPINTO
# 3839    0439136350        J.K.ROWLING
# 5431    0439139597        J.K.ROWLING
# 5432    0439064864        J.K.ROWLING
# 11765   8807813025  ALESSANDR.BARICCO
# 17420   1558746099       JAC.CANFIELD
# 25676   0425155188           J.D.ROBB
# 111751  0486296024        THOMA.PAINE
# 118722  0393974871         M.H.ABRAMS
# 155166  0812036875     HELG.FRITZSCHE
# 169193  0385196156     ANTHON.D.MELLO
# 192191  037570633X         ELIZ.MINOT
# 231809  1576736997    ROBI.LE.HATCHER
# 248790  039591910X            H.A.REY
#
#                                                Book-Title  \
# 1721    AS NATURE MADE HIM THE BOY WHO WAS RAISED AS A...
# 3839      HARRY POTTER AND THE PRISONER OF AZKABAN BOOK 3
# 5431           HARRY POTTER AND THE GOBLET OF FIRE BOOK 4
# 5432       HARRY POTTER AND THE CHAMBER OF SECRETS BOOK 2
# 11765                              NOVOCENTO, UN MONOLOGO
# 17420   CHICKEN SOUP FOR THE KID'S SOUL  101 STORIES O...
# 25676                                    RAPTURE IN DEATH
# 111751                 COMMON SENSE DOVER THRIFT EDITIONS
# 118722         THE NORTON ANTHOLOGY OF ENGLISH LITERATURE
# 155166  BANTAMS HUSBANDRY AND CARE, DISEASES, AND BREE...
# 169193                               THE SONG OF THE BIRD
# 192191                THE TINY ONE VINTAGE CONTEMPORARIES
# 231809                                      THE STORY JAR
# 248790                   CURIOUS GEORGE FEEDS THE ANIMALS
#
#         Year-Of-Publication                    Publisher Language
# 1721                   2000     HARPERCOLLINS PUBLISHERS       EN
# 3839                   1999                   SCHOLASTIC       EN
# 5431                   2000                   SCHOLASTIC       EN
# 5432                   1999                   SCHOLASTIC       EN
# 11765                  2003              DISTRIBOOKS INC       EN
# 17420                  1998                          HCI       EN
# 25676                  1996     BERKLEY PUBLISHING GROUP       EN
# 111751                 1997           DOVER PUBLICATIONS       EN
# 118722                 1999    W.W. NORTON &AMP; COMPANY       EN
# 155166                 1986  BARRON'S EDUCATIONAL SERIES       NO
# 169193                 1984                        IMAGE       EN
# 192191                 2000            VINTAGE BOOKS USA       EN
# 231809                 2001                    MULTNOMAH       EN
# 248790                 1998          HOUGHTON MIFFLIN CO       EN
